# %%
days=[1,2,3,4,5]
# list comprehension
# days = [_for_in range(1,5)]

days = [ 1,2,3,4,5]
sales=[12,18,15,23,27]
# 시각화를 하면 얼마나 증가했는지 알 수 있다
print(sales)
# Out:
# [12, 18, 15, 23, 27]

# %%
import matplotlib.pyplot as plt

plt.plot(days,sales)

plt.show()

# %%
plt.bar(days,sales)
plt.show()
