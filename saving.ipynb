# %%
import matplotlib.pyplot as plt

months = [ 1,2,3,4,5,6]
sales=[120,135,128,160,175,190]

fig,ax=plt.subplots(figsize=(8,6))   #그림 전체 = fig

ax.plot(
    months,
    sales,
    marker='o'
)

fig.savefig('monthly_sales.png')   #' ' 안에 쓴 건 경로

plt.show()
